# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot
from openml import evaluations
from openml import study
benchmark_suite = study.get_study('OpenML100','tasks') # obtain the benchmark suite

# Download and group the evaluation data
scores = []
for task_id in benchmark_suite.tasks: # iterate over all tasks. Can be removed if list_evaluations used paging!
    evaluations = oml.evaluations.list_evaluations(task=[task_id], function='area_under_roc_curve', size=200)
    for id, e in evaluations.items():
        scores.append({"dataset":e.data_name, "score":e.value})
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f69b474ff98>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda/envs/py3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: /api/v1/xml/study/OpenML100/tasks?api_key= (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f69b474ff98>: Failed to establish a new connection: [Errno 110] Connection timed out',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-c2101f9057d6> in <module>()
#       4 from openml import evaluations
#       5 from openml import study
# ----> 6 benchmark_suite = study.get_study('OpenML100','tasks') # obtain the benchmark suite
#       7
#       8 # Download and group the evaluation data
#
# ~/work/code/external/openml-python/openml/study/functions.py in get_study(study_id, type)
#      22     if type is not None:
#      23         call_suffix += "/" + type
# ---> 24     xml_string = _perform_api_call(call_suffix)
#      25     result_dict = xmltodict.parse(xml_string)['oml:study']
#      26     id = int(result_dict['oml:id'])
#
# ~/work/code/external/openml-python/openml/_api_calls.py in _perform_api_call(call, data, file_dictionary, file_elements, add_authentication)
#      50         return _read_url_files(url, data=data, file_dictionary=file_dictionary,
#      51                                file_elements=file_elements)
# ---> 52     return _read_url(url, data)
#      53
#      54
#
# ~/work/code/external/openml-python/openml/_api_calls.py in _read_url(url, data)
#     110     if len(data) == 0 or (len(data) == 1 and 'api_key' in data):
#     111         # do a GET
# --> 112         response = requests.get(url, params=data)
#     113     else: # an actual post request
#     114         # Using requests.post sets header 'Accept-encoding' automatically to
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/miniconda/envs/py3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: /api/v1/xml/study/OpenML100/tasks?api_key= (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f69b474ff98>: Failed to establish a new connection: [Errno 110] Connection timed out',))
